# %%
# pip install ydata-profiling
from ydata_profiling import ProfileReport
import pandas as pd
df = pd.read_csv("lifestyle_sustainability_data.csv")

# Generate the data profiling report, title is just 
report = ProfileReport(df, title='Sustainability dataset, Advanced Data Analytics -course')

# create either an HTML -page or show it straight in the notebook
# sometimes the HTML -page is easier to browse!
report.to_file("ydata_lifesustainability_data_report.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 400.41it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Additional information regarding the lifestyle report example

# %%
# let's see the correlations like this too
df.corr(numeric_only=True)['Rating']
# Out:
# ParticipantID                    0.114871
# Age                             -0.062691
# HomeSize                         0.041610
# SustainableBrands                0.512563
# EnvironmentalAwareness           0.589104
# MonthlyElectricityConsumption   -0.571783
# MonthlyWaterConsumption         -0.557345
# Rating                           1.000000
# Name: Rating, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
