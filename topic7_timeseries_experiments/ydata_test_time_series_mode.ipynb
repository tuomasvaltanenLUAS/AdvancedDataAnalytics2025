# %% [markdown]
# ### Ydata testing with time-series mode!

# %% [markdown]
# Ydata also has a time series mode, which is quite useful for basic analysis in time series datasets (or sequential datasets in general).

# %% [markdown]
# This data is a fairly common Air quality dataset, lots of missing values etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# load dataset
file_path = "AirQualityUCI.csv"
data = pd.read_csv(file_path, sep=";", decimal=",")

# Manually format the 'Date' and 'Time' columns into a proper datetime format
# First, replace the '.' in 'Time' column with ':' to make it a valid time format
data['Time'] = data['Time'].str.replace('.', ':')

# Combine the 'Date' and 'Time' into a single datetime column
data['Datetime'] = pd.to_datetime(data['Date'] + ' ' + data['Time'], dayfirst=True)

# Select relevant columns
columns = ["Datetime", "CO(GT)", "PT08.S1(CO)", "NMHC(GT)", "C6H6(GT)", "T", "RH", "AH"]
data = data[columns]

# # saving this if needed later
# # Replace -200 with NaN for all numerical columns
# numerical_cols = data.select_dtypes(include=[np.number]).columns  # Select numerical columns
# data[numerical_cols] = data[numerical_cols].replace(-200, np.nan)

# Drop rows with too many NaNs
data = data.dropna()

# Display the first few rows
print(data.head())
# Out:
#              Datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)     T    RH  \
# 0 2004-03-10 18:00:00     2.6       1360.0     150.0      11.9  13.6  48.9
# 1 2004-03-10 19:00:00     2.0       1292.0     112.0       9.4  13.3  47.7
# 2 2004-03-10 20:00:00     2.2       1402.0      88.0       9.0  11.9  54.0
# 3 2004-03-10 21:00:00     2.2       1376.0      80.0       9.2  11.0  60.0
# 4 2004-03-10 22:00:00     1.6       1272.0      51.0       6.5  11.2  59.6
#
#        AH
# 0  0.7578
# 1  0.7255
# 2  0.7502
# 3  0.7867
# 4  0.7888

# %% [markdown]
# <b>Ydata-profiling is quite solid also for time series, but remember to use tsmode=True!</b>

# %%
from ydata_profiling import ProfileReport

# Generate a profile report
profile = ProfileReport(data, tsmode=True, sortby="Datetime", title="Multivariate Time-Series Analysis")
profile.to_file("air_quality_profile.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
